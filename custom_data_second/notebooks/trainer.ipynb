# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/projects/yolov3_pavement/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/projects/yolov3_pavement/darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 8.98 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.
# Updating files: 100% (2056/2056), done.

# %%
# !ls -a '/content/drive/MyDrive/projects/yolov3_pavement/custom_data_second'
# Out:
# Archive.zip  classes.names	 __MACOSX  test.txt  train.txt	yolov3-custom-second.cfg
# backup	     labelled_data.data  test	   train     valid

# %%
# !rm -rf '/content/drive/MyDrive/projects/yolov3_pavement/custom_data_second'

# %%
# !unzip '/content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/Archive.zip' -d '/content/drive/MyDrive/projects/yolov3_pavement/custom_data_second'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/__MACOSX/train/._img-448_jpg.rf.b48f430befc577cfc13eae2b23d3a31e.jpg
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/train/13_jpg.rf.90f04c5e9f570ed175c860ba3c7a6009.txt
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/__MACOSX/train/._13_jpg.rf.90f04c5e9f570ed175c860ba3c7a6009.txt
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/train/cracking1-184-_jpg.rf.60be1472863ff123f846d5fe7fc8daa2.txt
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/__MACOSX/train/._cracking1-184-_jpg.rf.60be1472863ff123f846d5fe7fc8daa2.txt
#   inflating: /content/drive/MyDrive/projects/yolov3_pavement/custom_data_second/train/us14-73-_jpg.rf.c3755a915ca2f37b95c3f351ffe05beb.txt
# ...

# %%
# %cd '/content/drive/MyDrive/projects/yolov3_pavement/darknet'
# Out:
# /content/drive/MyDrive/projects/yolov3_pavement/darknet

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# %cd '/content/drive/MyDrive/projects/yolov3_pavement'
# !ls
# Out:
# /content/drive/MyDrive/projects/yolov3_pavement
# backup	  chart_old.png  chart_yolov3-custom-second_old.png  custom_data_second
# bad.list  chart.png	 chart_yolov3-custom-second.png      darknet

# %%
# !chmod -R 777 darknet

# %%
# !darknet/darknet detector train custom_data_second/labelled_data.data custom_data_second/yolov3-custom-second.cfg backup/yolov3-custom-second_last.weights -gpus 0 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.590376), count: 7, class_loss = 0.920032, iou_loss = 0.610331, total_loss = 1.530363
#  total_bbox = 97092, rewritten_bbox = 0.080336 %
# 9539/12000: loss=1.2 hours left=3.4
#  9539: 1.184823, 1.404034 avg loss, 0.000100 rate, 2.904641 seconds, 610496 images, 3.377816 hours left
# Loaded: 0.000111 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.711558), count: 10, class_loss = 0.736155, iou_loss = 0.328176, total_loss = 1.064331
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.717179), count: 8, class_loss = 1.414099, iou_loss = 0.322543, total_loss = 1.736642
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.539567), count: 8, class_loss = 1.068341, iou_loss = 0.656807, total_loss = 1.725147
# ...
